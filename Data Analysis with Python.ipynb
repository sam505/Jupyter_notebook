# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("kc_house_data.csv")
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.401822e+05      3.370842      2.114757
# std     6239.28002  2.876566e+09  3.673622e+05      0.930062      0.770163
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# ## Question 1

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ## Question 2

# %%
df.drop(["id", "Unnamed: 0"], inplace=True, axis=1)
df
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 1      20141209T000000  538000.0         3       2.25         2570      7242
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 3      20141209T000000  604000.0         4       3.00         1960      5000
# 4      20150218T000000  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0         3       2.50         1530      1131
# 21609  20150223T000000  400000.0         4       2.50         2310      5813
# 21610  20140623T000000  402101.0         2       0.75         1020      1350
# 21611  20150116T000000  400000.0         3       2.50         1600      2388
# 21612  20141015T000000  325000.0         2       0.75         1020      1076
#
# ...

# %% [markdown]
# ## Question 3

# %%
df.floors.value_counts().to_frame()
# Out:
#         count
# floors
# 1.0     10680
# 2.0      8241
# 1.5      1910
# 3.0       613
# 2.5       161
# 3.5         8

# %% [markdown]
# ## Question 4

# %%
sns.boxplot(data = df, x='waterfront', y='price', hue="waterfront");

# %% [markdown]
# ## Question 5

# %%
sns.regplot(data=df, x='sqft_above', y='price');

# %% [markdown]
# ## Question 6

# %%
X = df[['sqft_living']]
Y = df['price']
linear_model = LinearRegression()
linear_model.fit(X,Y)
print("R^2 Score: ", end="")
print(r2_score(Y, linear_model.predict(X)))
# Out:
# R^2 Score: 0.49286538652201417

# %% [markdown]
# ## Question 7

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above", "grade", "sqft_living"]

X = df[features]
Y = df[["price"]]

l_model = LinearRegression()
l_model.fit(X, Y)

print(f"R^2 Score: {r2_score(Y, l_model.predict(X))}")
# Out:
# R^2 Score: 0.6575383623573035

# %% [markdown]
# ## Question 8

# %%
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

pipe=Pipeline(Input)
pipe.fit(X,Y)

print(f"R^2 Score: {r2_score(Y, pipe.predict(X))}")
# Out:
# R^2 Score: 0.7513390339619974

# %% [markdown]
# ## Question 9

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
Rig_model = Ridge(alpha=0.1)
Rig_model.fit(X_train,y_train)

print(f"R^2 Score: {r2_score(y_test, pipe.predict(X_test))}")
# Out:
# R^2 Score: 0.7652413497130471

# %% [markdown]
# ## Question 10

# %%
pf = PolynomialFeatures(degree=2)

X_train_pf = pf.fit_transform(X_train)
X_test_pf = pf.fit_transform(X_test)

rig_pf_model = Ridge(alpha=0.1)
rig_pf_model.fit(X_train_pf, y_train)

print(f"R^2 Score: {r2_score(y_test, rig_pf_model.predict(X_test_pf))}")
# Out:
# R^2 Score: 0.741240482734091
